# %% [markdown]
# # Dictionaries

# %% [markdown]
# #Define:-
# A dictionary is a built-in data type in Python that stores data in the form of key–value pairs. It allows fast and easy access to values using unique keys.
#
# A dictionary in Python function simiarly similarly to dictionary in real life.It's a data structure that allow us to associate a key to a value and pair the two pieces of data together.
#
# This is how you create a dictionary in python:

# %% [markdown]
# # An example dictionary.
#
# colours = {"apple":"red",
#            "pear":"green",
#            "banana":"yellow"}
#
# This is how retrieve items from a dictionary:
#
# print(colours["pear"])
# #will print "green"
#
# This is how you retrieve items from a dictionary:
#  my_empty_dictionary = {}
#
# This is how you can add new items to an existing dictionary:
# colours["peach"] = "pink"
#
# This is also how can edit an existing value in a dictionary:
#
# colours["peach"] = "green"
#
# This is also how you can edit an existing value in a dictionary:
#
# colours["apple"] = "green"
#
# This is how to loop through a dictionary and print all the

# %%
from IPython.display import HTML

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Table</title>
# </head>
# <body>
#
# <h1>Key and Value</h1>
#
# <table border="1">
#     <tr>
#         <th>Bug</th>
#         <th>Function</th>
#         <th>Loop</th>
#     </tr>
#
#     <tr>
#         <td>An error in a program that prevents it from running correctly</td>
#         <td>A block of code that can be reused multiple times</td>
#         <td>Repeating a task again and again</td>
#     </tr>
# </table>
#
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Table</title>
# </head>
# <body>
#
# <h1>Key and Value</h1>
#
# <table border="1">
#     <tr>
#         <th>Bug</th>
#         <th>Function</th>
#         <th>Loop</th>
#     </tr>
#
#     <tr>
#         <td>An error in a program that prevents it from running correctly</td>
#         <td>A block of code that can be reused multiple times</td>
#         <td>Repeating a task again and again</td>
#     </tr>
# </table>
#
# </body>
# </html>

# %% [markdown]
# #Note :- Add multiple value key and value  in the same dictionary.

# %% [markdown]
# #for example:-
#   {Key: Value}
#
#      1.:- Key    :Bug
#     Value  :An error in a program that prevents the                  prgoram from running as expected.

# %%
programming_dictionary = {
    "Bug": "An error in a program that prevents the program from running as expected.",
    "Function": "A piece of code that you can easily call over and over again.",
    "Loop": "Repeating a task again and again"
}

# Print value of a key
print(programming_dictionary["Function"])

# Update value
programming_dictionary["Bug"] = "A moth in your computer."

# Loop through dictionary
for key in programming_dictionary:
    print(key)
    print(programming_dictionary[key])
# Out:
# A piece of code that you can easily call over and over again.
# Bug
# A moth in your computer.
# Function
# A piece of code that you can easily call over and over again.
# Loop
# Repeating a task again and again

# %% [markdown]
# # Nested List And Dictonaries
#
# :-Ypu can mix and match various data types to achieve your desired structure.
#
# ypu can nest a List in a Dictionary like this :
#
# my_dictionary = { key1: [List],
#                   key2: Value,
#                   }
#
# you can also nest a dictionary in a dictionary:

# %%
#code
# Simple dictonaries

capitals = { "france":"paris","Germany":"Berlin"}
print(capitals)
# Out:
# {'france': 'paris', 'Germany': 'Berlin'}

# %% [raw]
# #Code
# #Nested List in Dictionary.
#
# #travel_log ={ "France": "paris", "lille", "dijon",}
# #print(travel_log)
# :-
# this code is invalid because 1. A dictionary must have key : value pairs.
# ,"lille" and " dijion" are written without keys, which is invalid. , if you want multiple cities for one country, you must use a list as the value.

# %%
# correct code :

travel_log = {
    "France": ["paris", "lille", "dijon"],
    "germany":["Stuttgart","Berlin"],
}
print(travel_log)
# Out:
# {'France': ['paris', 'lille', 'dijon'], 'germany': ['Stuttgart', 'Berlin']}

# %% [markdown]
# #PAUSE 1:
# See if you can figure out how to print out "lille" from the nested list called travel_log.
#
# #Code:- travel_log = {"France":["paris","lille","dijon"], "Germany" :["Stuttgart", "Berlin"],}
#
# #HINT :
# Nesting Lists inside other Lists
#
# we're previously seen Nested Lists:
#
# nested_list = ["A","B","C","D"]
#
# #NESTING LIST inside other lists.
#
#     We've previously seen Nested Lists:
#     #code
#     nested_list = ["A","B",["C","D"]

# %%
#How print lille in the france list :
print(travel_log["France"][1])
# Out:
# lille

# %%
#NOTE :- list inside the list it's called nested list for example:
nested_list = ["A","B",["C","D"]] # it's also called 2D list.
#How to print out "D" in the nested_list
print(nested_list[2]) # if you are code nested_list[2] then print "C" and "D"
print(nested_list[2][0]) # it's print "C" when you are write list inside the list index number.
# Out:
# ['C', 'D']
# C

# %% [markdown]
# # Note :-
# 1.Nested List (2D List) Example:-
#
#     nested_list = ["A", "B", ["C", "D"]]
#
# 2.Accessing Elements from a Nested List
#
#     input
#     print(nested_list[2])
#
#
#     output
#     ['C', 'D'] # This prints the entire inner list at index 2.
#
# 3.     input
#        print(nested_list[2][0])
#         output:C
#
# i.First [2] selects the inner list ["C", "D"]
# ii.Second [0] selects "C" from that inner list.

# %% [markdown]
# # Nesting a Dictionary inside a Dictionary
# You can also nest a dictionary in a dictionary:
#
#     #SYNTAX
#
#     my_dictionary ={key1:value,
#                     key2:value, key:value},
#                     }
#
# #PAUSE 3
#
# Figure out how to print out "Stuttgart" from the folling list:
#
# #code:
#
# travel_log = {"France":{"cities_visited":["paris","lille","dijon"],
#                         "total_visits":12}
#               "germany":{"cities_visited":["berlin","hamburg","stuttgart"],"totel_visits":5},}

# %%
#code:
travel_log1 = {"france":{"cities_visited":["paris","lille","dijon"],
                        "total_visits":12}, "Germany":{"cities_visited":["berlin","hamburg","stuttgart"],
                                                       "total_visite":5},}

#print(travel_log1)

# print(travel_log1["Germany"]["cities_visited"])

print(travel_log1["Germany"]["cities_visited"][2])
# Out:
# stuttgart

# %% [markdown]
# # The Secret Auction Program instructions and Flow Chart

# %% [markdown]
# # The goal is to build a blind auction program
#
#
#
# 1. Clearing the output
#
#    :-There are several ways of clearing the output. The easiest is to simple print "\n" many time so that the output scrolls down many lines.
#
#        e.g:-
#        #1.this will add 20 new lines to the output
#        print("\n"*20)
#
# The alternative is to use the system function:
#
#     from os import system
#
#     #2.On Windows
#     system("cls")
#
#     #3.On Mac or linux
#     system("clear")
#
# But you might get an error that says TERM environment variable not set.
#
# In that cases you need to go into settings, to emulate the terminal. Run -> Edit Configurations ->Modify
# Options -> Emulate terminal in output console

# %%
# print("hello")
# print("\n" * 100) # 100 time multiple 
# input("Type Someting")

# %% [markdown]
# # project

# %%
from IPython.display import HTML, display

html_code = """
<style>
body {
    font-family: Arial, sans-serif;
    background-color: #f4f6f7;
    text-align: center;
}

.box {
    border: 2px solid #333;
    padding: 12px;
    margin: 12px auto;
    width: 420px;
    background-color: #ffffff;
    border-radius: 8px;
}

.decision {
    border: 2px dashed #333;
    background-color: #fff3cd;
}

.arrow {
    font-size: 22px;
    margin: 5px;
}
</style>

<h1>Bidding Program Flowchart</h1>

<div class="box">Start</div>
<div class="arrow">⬇</div>

<div class="box">Show logo  (from art.py)</div>
<div class="arrow">⬇</div>

<div class="box">Ask for Name input</div>
<div class="arrow">⬇</div>

<div class="box">If NO then Clear Screen</div>
<div class="arrow">⬇</div>


<div class="box">Clear Screen</div>
<div class="arrow">⬇</div>

<div class="box">Ask For Bid Price</div>
<div class="arrow">⬇</div>

<div class="box">Add Name And Bid into a dictionary as the key and value<br>(name : bid)</div>
<div class="arrow">⬇</div>

<div class="box decision">
 Are there other users who want to bid?
</div> # Ask if there are any other users who would like to place a bid. If the answer is 'YES', clear the screen and continue the bidding process. If the answer is 'NO', find the highest bid in the dictionary and declare that user as the winner.   
   

<div class="arrow">⬇ YES</div>
<div class="box">Clear Screen</div>
<div class="arrow">⬇</div>
<div class="box">Ask Next User Name</div>

<div class="arrow">⬇ NO</div>
<div class="box">Find the highest bid in the dictionary and declare them as the winner</div>
<div class="arrow">⬇</div>

<div class="box">Declare Winner</div>
<div class="arrow">⬇</div>

<div class="box">End</div>
"""

display(HTML(html_code))
# Out:
# <style>
# body {
#     font-family: Arial, sans-serif;
#     background-color: #f4f6f7;
#     text-align: center;
# }
#
# .box {
#     border: 2px solid #333;
#     padding: 12px;
#     margin: 12px auto;
#     width: 420px;
#     background-color: #ffffff;
#     border-radius: 8px;
# }
#
# .decision {
#     border: 2px dashed #333;
#     background-color: #fff3cd;
# }
#
# .arrow {
#     font-size: 22px;
#     margin: 5px;
# }
# </style>
#
# <h1>Bidding Program Flowchart</h1>
#
# <div class="box">Start</div>
# <div class="arrow">⬇</div>
#
# <div class="box">Show logo  (from art.py)</div>
# <div class="arrow">⬇</div>
#
# <div class="box">Ask for Name input</div>
# <div class="arrow">⬇</div>
#
# <div class="box">If NO then Clear Screen</div>
# <div class="arrow">⬇</div>
#
#
# <div class="box">Clear Screen</div>
# <div class="arrow">⬇</div>
#
# <div class="box">Ask For Bid Price</div>
# <div class="arrow">⬇</div>
#
# <div class="box">Add Name And Bid into a dictionary as the key and value<br>(name : bid)</div>
# <div class="arrow">⬇</div>
#
# <div class="box decision">
#  Are there other users who want to bid?
# </div> # Ask if there are any other users who would like to place a bid. If the answer is 'YES', clear the screen and continue the bidding process. If the answer is 'NO', find the highest bid in the dictionary and declare that user as the winner.
#
#
# <div class="arrow">⬇ YES</div>
# <div class="box">Clear Screen</div>
# <div class="arrow">⬇</div>
# <div class="box">Ask Next User Name</div>
#
# <div class="arrow">⬇ NO</div>
# <div class="box">Find the highest bid in the dictionary and declare them as the winner</div>
# <div class="arrow">⬇</div>
#
# <div class="box">Declare Winner</div>
# <div class="arrow">⬇</div>
#
# <div class="box">End</div>

# %% [markdown]
# #NOTE:
#
# (In Hindi)
#
#      1.Project ka flowchart maine HTML aur CSS ke through design kiya hai, taaki project banana easy ho aur humein step by step clear rahe ki kya karna hai aur kya nahi karna hai.
#
#      (In English)
#
#     2.I have designed the project flowchart using HTML and CSS so that building the project becomes easier and we have a clear step-by-step understanding of what needs to be done and what does not.

# %%
## TODO-1: Ask the user for input
      # name = input("Wjat is your name?: ")
            # price = int(input("What is your bid?: $"))

# bids = {}

                 ## TOD0-2: Save data into dictionary {name: price}
# bids[name] = price

              ## TODO-3: Whether if new bids need to be added 
                                             # should_continue = input("Are there any other bidder? Type 'yes' or 'no'.\n")

   ## TODO-4: Compare bids in dictionary
bids = {}
continue_bidding = True

while continue_bidding:
    name = input("What is your name?: ")
    price = int(input("What is your bid?: $"))
    bids[name] = price

    should_continue = input("Are there any other bidders? Type 'yes' or 'no': ").lower()
    if should_continue == "no":
        continue_bidding = False


def find_highest_bidder(bidding_dictionary):
    highest_bid = 0
    winner = ""

    for bidder in bidding_dictionary:
        bid_amount = bidding_dictionary[bidder]
        if bid_amount > highest_bid:
            highest_bid = bid_amount
            winner = bidder

    print(f"The winner is {winner} with a bid of ${highest_bid}.")


find_highest_bidder(bids)
# Out:
# What is your name?:  Megha Thakur
# What is your bid?: $ 13
# Are there any other bidders? Type 'yes' or 'no':  yes
# What is your name?:  nisha thakur
# What is your bid?: $ 12
# Are there any other bidders? Type 'yes' or 'no':  no
# The winner is Megha Thakur  with a bid of $13.
