# %%
# TODO : asking the qustion 
# TODO : checking if the answer was correct 
# TODO : checking if we're the end of

# %%
from question_model import Question
from data import question_data
from quiz_brain import QuizBrain

question_bank = []
for question in question_data:
    question_text = question["text"]
    question_answer = question["answer"]
    new_question = Question(question_text, question_answer)
    question_bank.append(new_question)
    question_bank.append(new_question)
    # print(new_question)

# print(question_bank)
# print(question_bank[0])

quiz = QuizBrain(question_bank)
# Create while loop after add one more method that : still_has_question()

while quiz.still_has_question(): # if quiz still has questions remaining:
    quiz.next_question()

print("you've completed the quiz")
print(f"your final score was: {quiz.score}/{quiz.question_number}")

# "you've completed the quiz"
# "your final score was: 10/12" Question
# Out:
# Q.1:A slug's blood is green. (True/false): true
# you got it right!
# Te correct answer was: True.
# your current score is: 1/1
# Q.2:A slug's blood is green. (True/false): true
# you got it right!
# Te correct answer was: True.
# your current score is: 2/2
# Q.3:The loudest animal is the African Elephant. (True/false): true
# That's wrong.
# Te correct answer was: False.
# your current score is: 2/3
# Q.4:The loudest animal is the African Elephant. (True/false): false
# you got it right!
# Te correct answer was: False.
# your current score is: 3/4
# Q.5:Approximately one quarter of human bones are in the feet. (True/false): true
# you got it right!
# Te correct answer was: True.
# your current score is: 4/5
# Q.6:Approximately one quarter of human bones are in the feet. (True/false): true
# you got it right!
# Te correct answer was: True.
# your current score is: 5/6
# Q.7:The total surface area of a human lungs is the size of a football pitch. (True/false): false
# That's wrong.
# ...
