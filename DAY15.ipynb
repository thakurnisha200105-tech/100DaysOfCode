# %% [markdown]
# # OOPs (Object-Oriented Programming)
#
# OOPs is a programming approach that is based on classes and objects.
# In simple words, OOPs is a way to represent real-world entities in programming.
#
# # Main Concepts of OOPs
#
# There are two important terms in OOPs:
#
# 1. Object
#
# An object is any real-world entity.
# For example: mouse, keyboard, pen, car, student — all these are objects.
# Each object has its own data and behavior.
#
# 2. Class
#
# A class is a blueprint or template used to create objects.
#
# Example:
# Imagine a car factory.
# The factory uses one blueprint to manufacture many cars like X, Y, and Z.
# Even though all cars are different units, they have the same features and functions because they are created from the same blueprint.
#
#
# # OOPs in Python
#
# In Python, objects are not created directly.
# First, we define a class, and then we create objects from that class.
#
#      Simple Real-Life Example
#
#      School example:
#      Agar hum school me ek class (Class) banate hain,to us class ke andar jitne bhi students (bacche) hote hain,woh sab objects kehlate hain.
#
#
#
#
# # OOP Example (Chair & Table)
#
# In Object Oriented Programming (OOPs), a class is like a blueprint of a real-world object.
#
#     For example:
#     A Chair usually has:
#     4 legs
#     1 seat
#     1 back support
#
# So, we can say:
#
#     A chair is a type of furniture that has four legs and a back support.
#     This definition (features of a chair) works like a blueprint.
#
#     Now, if we remove the back support, the furniture becomes a Table.
#
#                  That means:
#
#       Chair and Table are related
#       Both have 4 legs
#       Chair has an extra feature (back support)
#
#                 This is how OOP works:
#
#       Chair = Class (blueprint)
#       Real chair in your house = Object
#       Legs, seat, back support = Attributes

# %% [markdown]
# # Class:
# A class is a blueprint or template used to create objects.
#
# (1) creating class
#
#            class Student :           #  oject sould be alway capital .
#                 name="nisha thakur"  # nisha is a buleprint
#
#                                      # creating object (instance)
#
#             S1=Student()             # it's called object.
#             print(S1.name)

# %%
# code1.1
class car:
    colour = "blue"
    brand = "mercedes"
    
car1 = car() #create object
print(car1.colour) # attributes
print(car1.brand)

# %% [markdown]
# # Constructor (Python)
#
# 1.Jab hum kisi class ka object create karte hain, tab constructor automatically call ho jata hai aur object ki initial values set karta hai.
#
# 2.Constructor ko special function isliye kaha jata hai kyunki:
#
#     Ye automatically call hota hai
#     Hume ise manually call karne ki zarurat nahi hoti
#
# 3.Agar hum Python me constructor define nahi karte, toh Python khud ek default constructor provide kar deta hai.
#
# # Interview Question
#
# Q. What is the purpose of a constructor?
#
# Answer:
# The main purpose of a constructor is:
#
#     To create the object
#     To initialize the object with initial values at the time of object creation
#
# # Definition
#
# A constructor is a special method that gets called automatically when an object of a class is created.
#
# # Important Points
#
#     Constructor har class ke liye create hota hai
#     Python me constructor ka naam __init__() hota hai
#     self ek reference variable hota hai jo current object ko refer karta hai
#
#     # For Example:-

# %%
hgiuguyfyf

# %% [markdown]
# # Here important question:-
#
# Question1 :- In this code attributes are the variables or something else?
# Answer    :- Attributes are variables, but not normal variables.
#              They are class attributes or object attributes.
#
# Question2 :- What is an attribute?
# Answer    :- An attribute is a variable that belongs to a class or an object.
#
# #In the code1.1
#
# colour = "blue"
# brand  = "mercedes" # these are class attributes
#
# Question3 :- Why are they called attributes and not just variables?
# Answer    :- Because:
#
#      Normal variable → exists independently
#      Attribute → belongs to a class or object
#
# Example:
#
#        x = 10        # normal variable
#        car1.colour  # attribute (belongs to car1 object)
#
#  # Types of attributes

# %% [markdown]
# :- In Python OOP, attributes are mainly of TWO types:
#
#       1.Class attributes
#       2.Instance (object) attributes

# %% [markdown]
# # Class Attributes:
#
#      1.Defined inside the class
#      2.Outside any method
#      3.Shared by all object
# #For example:
#
#      class Car:
#          wheels = 4 # class attribute
#
#     *Access:
#
#      print(Car.wheels)
#      print(Car1.wheels)

# %%
# code1.2

class Car:
    wheels = 4

#Access:
print(Car.wheels)

car1 = Car()          # create object
print(car1.wheels)

# %% [markdown]
# # Instance (Object) Attributes
#
#     1.Defined using self
#     2.Usually inside __init__() # __init__ is a constructor :-_init__() is called      automatically when an object is created, so it works like a constructor.
#     3.Different for each object

# %% [markdown]
# # NOTE :-
# Jab programmer kuch define nahi karta, aur Python khud kaam kar deta hai — usse default kehte hain.
#
# OR
#
# Default in Python means the value or behavior that Python provides automatically when the programmer does not specify anything.
#
# For Example :-

# %%
class Student:
    pass   # no constructor written

s = Student()   # object created
print("Object created successfully")

# %%
#cose1.2
class Faculty:
    def __init__(self): # method1
        self.id =   int(input("Enter Faculty id:"))
        self.name = input("Enter your name:")
        self.salary = float(input("Enter faculty salary:"))

    def display(self): # method2
            print("Faculty ID:", self.id)
            print("Faculty Name:", self.name)
            print("Faculty Salary:", self.salary)


a= Faculty()
b= Faculty()
c= Faculty()
a.display()
b.display()
c.display()

# %% [markdown]
# # Exter parameter pass

# %%
class Faculty:
    def __init__(self, a, b, c):  # constructor
        self.f_id = a
        self.name = b
        self.salary = c

    def display(self):
        print(f"Faculty ID: {self.f_id}")
        print(f"Faculty Name: {self.name}")
        print(f"Faculty Salary: {self.salary}")


a = Faculty(1, "Nisha Thakur", 2000)
a.display()

# %% [markdown]
# # oops (Class and instance attributes)

# %%
class Student:
    university = "Amity university "      # class attribute

    def __init__(self, studentid, studentname):
        self.studentid = studentid      # instance attribute
        self.studentname = studentname  # instance attribute


# creating objects
c1 = Student(111, "Shivam")
c2 = Student(222, "Nisha")
c3 = Student(333, "Umesh")

print(c1.studentid)       # 111
print(c1.studentname)     # Ram

print(Student.university)     # amity university ----class attribute calls 
print(c1.university)          # amity university 

c1.studentid = 555            # “These two lines mean that we are changing the student’s ID for object c1,
                              #  and we are also updating the school (university) name for the entire class.”
Student.university = "AIIT"

# %% [markdown]
# # Note :-
# Methods
#
#     Methods wo functions hote hain jo class ke andar define hote hain aur object se belong karte hain.
#     Methods ka use object ke data (attributes) par kaam karne ke liye hota hai.
#
#
# OR
#
#     A class is a blueprint that contains data (attributes) and methods (functions that define the behavior of an object.

# %% [markdown]
# # Turtle
#  :- turtle is a module, and it comes built-in with Python.So you do NOT need to install it separately.
#  * Python standard library → contains many modules
#  * turtle → one of those standard modules
#
#  #  What do you mean by turtle? 🐢
# turtle is a graphics module in Python.
# It works like this:
# * Imagine a small turtle (pen) on the screen
# * The turtle can:
#     * move forward / backward
#     * turn left / right
#     * draw lines as it moves
# The drawing happens step-by-step, so you can see the logic visually.

# %% [markdown]
# # Why do we use turle?
# We use turtle mainly for:
# * Learning Python easily (especially beginners)
# * Understanding programming concepts
# * Drawing shapes & designs
# You can draw
# * eaching kids & beginners
# That’s why turtle is very popular in.
#
# # What is the purpose of turtle?
# :- The main purpose of turtle is :
# To teach programming concepts using graphics.
#
# *  In simple words:
# :- turtle helps us learn coding by drawing pictures.

# %%
#Code2.1
import turtle

t = turtle.Turtle()
t.forward(100)
t.left(90)
t.forward(100)

turtle.done()

# %% [markdown]
# # NOTE(Code2.1)
# This code:
# * moves the turtle
# * draws two lines
# * helps you see what the code is doing

# %% [markdown]
# # There are some common used turtle function :-
#
# Movement functions
#
# * forward() / fd()
# * backward() / bk()
# * right() / rt()
# * left() / lt()
# * goto()

# %% [markdown]
# Drawing & color
#
# * color()
# * pensize()
# * penup()
# * pendown()
# * begin_fill()
# * end_fill()

# %% [markdown]
# Shape & speed
#
# * shape()
# * speed()
# * circle()

# %% [markdown]
# Screen control
#
# * Screen()
# * bgcolor()
# * title()
# * done()

# %%
#code2.2
import turtle
screen = turtle.Screen() # this function open new page 
                         #( the name of new page is Python Turtle Graphics)

# %%
#code2.3
import turtle
# Titel = Name of a window, page, book, or program
screen = turtle.Screen()
screen.title("My Turtle Window")

# %% [markdown]
# #Note :- car.speed .
#
# * car = object
# * speed = Attribute

# %%
# code2.3
import turtle 
nisha = turtle.Turtle()
nisha.shape()

# %%
# if you want to another shape it can be possible 
nisha.shape("turtle")

# %%
# if you want to check ki how many shape are provide turtle module then :
import turtle
help(turtle.shape)

# %% [markdown]
# # Note :-
# here in your output turtle provide 6 shape their are :-
# 'arrow', 'turtle', 'circle', 'square', 'triangle', 'classic'.

# %%
# if you want to check how many colour are provide turtle it can be also possible :-
nisha.color()

# %%
# apply movement function :
nisha.forward(100)

# %%
# if you want to change the colour of turtle it can be also possible :- 
nisha.color("red") 
# if i move forward then 
nisha.forward(200)

# %%
# if you want line color is different and turtle colour is different then :-
nisha.color("blue","green") # blue = blue is line colour and green is turtle colour.
nisha.backward(150)

# %%
# if you want to chnage the background colour then :-

# %% [markdown]
# # bgcolor() | title() | bgpic
#
# * bgcolor() :- Used to change the background color of the turtle window.
#
# * for example :-
#
#   import turtle
# screen = turtle.Screen()
# screen.bgcolor("blue")

# %%
#code 
import turtle

screen = turtle.Screen()      # create screen object
screen.bgcolor("pink")        # set background color

nisha = turtle.Turtle()       # create turtle object

turtle.done()                 # keep window open

# %% [markdown]
# * title():- Used to change the title of the turtle window(top bar name
#
# * for example :-
#
#        * import turtle
#          screen = turtle.Screen()
#          screen.title("My turtle program")

# %%
import turtle 
screen = turtle.Screen()
screen.title("My turtle program")

nisha = turtle.Turtle()
turtle.done()

# %% [markdown]
# #3. bgpic()
# * Used to set a background image in the turtle window.
# * For example:-
#
#   import turtle
#   Screen = turtle.Screen()
#   screen.bgpic("image.gif")

# %%
import turtle
screen = turtle.Screen()
screen.bgpic("image.git")

# %%
#NOTE :- wn = it's stand for windown

# %%
import turtle
amisha = turtle.Turtle()
amisha.color("red")
amisha.shape("turtel")
wn= turtle.Screen()
wn.bgcolor("black")

# %% [markdown]
# # Turtle Movement : forward() | backward() |left() |right()

# %%
import turtle 
t= turtle.Turtle()
t.setheading(90)

# %%
# code 
from turtle import Turtle, Screen
nnn = Turtle()
print(nnn)
nnn.shape("turtle")
nnn.color("coral")

# %%
# Link 
from IPython.display import HTML
display(HTML('<a href ="https://docs.python.org/3/library/turtle.html">Randpm module | W3school </a>'))

# %%
from IPython.display import HTML
display(HTML('<a href="https://docs.python.org/3/library/turtle.html" target="_blank">Turtle Module | Python Docs</a>'))

# %% [markdown]
# # Important note:
#
# 1. Module in Python
# 2. Package in Python
# 3. Library in Python
#
#
# #1.MODULE IN PYTHON :-
# * A module is a single Python file (.py) that contains:
#
#       functions
#       variables
#       classes
#
# * Simple words:
# Ek single Python file jisme code likha hota hai, usko module kehte hai.

# %%
# mymodule.py
def greet():
    print("Hello Nisha!")
